# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
import matplotlib.pyplot as plt

# %%
iris = load_iris()
X = iris.data

# %%
wcss = []
silhouette_scores = []
db_scores = []

# %%
cluster_range = range(2, 11)

# %%
for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(X)
    
    #
    silhouette_avg = silhouette_score(X, cluster_labels)
    db_index = davies_bouldin_score(X, cluster_labels)
    wcss_value = kmeans.inertia_  
    
    silhouette_scores.append(silhouette_avg)
    db_scores.append(db_index)
    wcss.append(wcss_value)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, cmap='viridis', marker='o', edgecolor='k', s=50)
plt.title('K-Means Clustering of Iris Dataset')
plt.xlabel('Feature 1 (Sepal Length)')
plt.ylabel('Feature 2 (Sepal Width)')
plt.show()

# %%
plt.figure(figsize=(16, 6))
print(f'Silhouette Score: {silhouette_avg:.4f}')
plt.subplot(1, 3, 1)
plt.plot(cluster_range, silhouette_scores, marker='o', linestyle='--', color='g')
plt.title('Silhouette Score vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
# Out:
# Silhouette Score: 0.5528
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 print(f'Silhouette Score: {silhouette_avg:.4f}')
#       3 plt.subplot(1, 3, 1)
# ----> 4 plt.plot(cluster_range, silhouette_scores, marker='o', linestyle='--', color='g')
#       5 plt.title('Silhouette Score vs. Number of Clusters')
#       6 plt.xlabel('Number of Clusters')
#
# NameError: name 'cluster_range' is not defined

# %%
plt.subplot(1, 3, 2)
plt.plot(cluster_range, db_scores, marker='o', linestyle='--', color='b')
plt.title('Davies-Bouldin Index vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Davies-Bouldin Index')
# Out:
# Text(0, 0.5, 'Davies-Bouldin Index')

# %%
plt.subplot(1, 3, 3)
plt.plot(cluster_range, wcss, marker='o', linestyle='--', color='r')
plt.title('WCSS vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Within-Cluster Sum of Squares (WCSS)')

plt.show()
